# %%
import os
os.environ["CATALOG_MANIFEST_PATH"] = "/Workspace/Users/fabiofumio@gmail.com/HandsOn_Beta/config/catalogs.json"

# %%
import runpy
import sys

sys.argv = [
    "databricks_catalogs.py",
    "--environment", "desenv",
    "--execution-mode", "spark",
    "--dry-run",
]

runpy.run_path(
    "/Workspace/Users/fabiofumio@gmail.com/HandsOn_Beta/scripts/01_databricks_catalogs.py",
    run_name="__main__",
)
